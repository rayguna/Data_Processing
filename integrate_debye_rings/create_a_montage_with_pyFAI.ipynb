# %% [markdown]
# ### Create a montage with pyFAI

# %% [markdown]
# ### TOC
# 1. [Make a Montage by Calling the Make_Montage Function Within the makepyfais Package](#1)
# 2. [Make a Montage Using the MakePyFAIs Class Within the makepyfais Package](#2)

# %% [markdown]
# ***

# %% [markdown]
# #### 1. Make a Montage by Calling the make_montage Function Within the makepyfais Package <a id="1"></a>

# %%
import makepyfais

makepyfais.make_montage(poni_path="poni", img_path="img", lst_labels=[], mask_path="mask")
# Out:
# Processing... Please wait...
# Only one poni file is applied to all image(s)
# One mask(s) is applied to all images. To apply separate masks, label mask file names according to the provided labels.
# Done!

# %% [markdown]
# #### 2. Make a Montage Using the MakePyFAIs Class Within the makepyfais Package<a id="2"></a>

# %%
import makepyfais

#%matplotlib qt #display image on a Qt widget
# %matplotlib inline
#or 
#%matplotlib qt

#make PyFAIs object. Specify labels as a list (optional)
pyFAIs=makepyfais.MakePyFAIs("poni")

#apply images and mask (optional)
dict_XRDs = pyFAIs.integrate("img")

#Create a montage
pyFAIs.create_a_montage()
# Out:
# Processing... Please wait...
# Only one poni file is applied to all image(s)
# Done!

# %% [markdown]
# ***
